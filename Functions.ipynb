# %% [markdown]
# #  Functions Assignment

# %% [markdown]
# Ques:-  What is the difference between a function and a method in Python?
#
# Answer:- The major difference between the function and method is that
# the function is not defined inside the class and  does not the parameter self
# ex:def add(a, b):
#     print("The sum of a and b is", a + b)
#
# but on  the other hand,  method is defined inside the class and it is used so that objects can access them and does include the self as parameter
# ex:- class Student:
#     def add(self, a, b):
#         print("The sum of a and b is", a + b)

# %% [markdown]
# Ques:-  Explain the concept of function arguments and parameters in Python
#
# Answer:- The Major difference between the arguments and parameter is that Parameters are the names used in the function definition to receive values.-
#
# ex:- def add (a,b )
#
# so a and b are the parameters
#
#  and on the other hand , Arguments are the actual values we pass to the function when calling it.
#
# ex:- add(3,4)
# so these 3 and 4 are the arguments

# %% [markdown]
# Ques 3:-  What are the different ways to define and call a function in Python?
#
# Answer:- n Python, we can define and call functions in different ways. A function is defined using the def keyword. We can create functions with parameters, default values, *args, and **kwargs.
#
# Different ways to define a function
# 1. Normal function
# def greet():
#     print("Hello, this is a simple function")
#
# 2. Function with parameters
# def add(a, b):
#     print(a + b)
#
# 3. Function with default parameter
# def add(a, b, c=0):
#     print(a + b + c)
#
# 4. Function with *args (multiple arguments)
# def show_numbers(*args):
#     print(args)
#
# 5. Function with **kwargs (keyword arguments)
# def student_info(**details):
#     print(details)
#
# Different ways to call a function
# 1. Calling a normal function
# greet()
#
# 2. Calling a function with arguments
# add(3, 5)
#
# 3. Calling a function with default argument
# add(4, 6)
#
# 4. Calling function with *args
# show_numbers(10, 20, 30, 40)
#
# 5. Calling function with **kwargs
# student_info(name="Ajay", age=21, city="Delhi")

# %% [markdown]
# Question 4:-  What is the purpose of the `return` statement in a Python function?
#
# Answer:- The return statement in a Python function is used to send a value back to the caller.
# It ends the function execution and returns the final result of the function.
#
# If a function does not have a return statement, it automatically returns None.
#
#  Example:-
# def add(a, b):
#     return a + b
#
# result = add(4, 6)
# print(result)

# %% [markdown]
# Question 5:-  What are iterators in Python and how do they differ from iterables?
#
# Answer :- The iterators are different from iterables because iterables are objects that can be looped over (for example in a for loop).
# Examples include list, tuple, string, dictionary, set, etc.
# They do not give values one by one directly, but they provide an iterator.
#
# An iterator is an object that returns data one element at a time using the __next__() method.
# Iterator is created from an iterable using the iter() function and we can fetch its values using next().

# %% [markdown]
# Ques 6:-  Explain the concept of generators in Python and how they are defined.
#
# Answer :- Generator function is that it calculates the value and provide output one by one instead of one go
#
# Generators are defined like normal functions, but instead of using return, they use the yield statement.
# Each time yield is executed, the function pauses and returns a value, and it resumes from the same point on the next call.
#
# eg:-  def numbers():
#
#     yield 1
#     yield 2
#     yield 3

# %% [markdown]
# Ques 7:-  What are the advantages of using generators over regular functions?
#
# Answer:- The advantage generator function have compare to regular function is that ;
#
# 1. memory utilsation:-  by using generator function we have low memory utilisation than regular function
#
# 2. less computation:- by using generator function , we have less computation than regular functon because it gives result one by one instead of one go
#
# 3. fast result: generator function is fast than regular function because insteading of providing the result in one go , it provides result one by one
#
# 4. useful for large data

# %% [markdown]
# Ques 8:-  What is a lambda function in Python and when is it typically used?
#
# Answer:- A lambda function in Python is a small anonymous function (a function without a name).
# It is also called a single-line function, because it does not use the def keyword and does not contain a return statement — the expression itself returns the value.
#
# syntax for lambda function is ;
#
# lambda arguments: expression
#
# we used lambda function , when we want to write the function in one line instead of many lines and lambda function is used in many functions like map(),filter() and reduce()

# %% [markdown]
# Question 9:-  Explain the purpose and usage of the `map()` function in Python.
#
# Answer:-map function() executes a specified function for each of item of an iterable
#
# syntax for map function():-
#
# map(func,*iterables)
#
# explain of map function:-
#
# l=[1,2,3,4,5]
#
# def square(x):
#   returnx**2
#
#   map(square,l)
#
#   so, the square function will execute for each item of l .

# %% [markdown]
# Ques 10:- What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?
#
# Answer:-map(), reduce(), and filter() are higher-order functions in Python that apply a function to a sequence (like list, tuple, etc.), but they behave differently.
#
#  1. map()
#
# Applies a function to every element in an iterable
#
# Returns a map object (iterator) with modified values
#
# Example:
#
# numbers = [1, 2, 3, 4]
# result = map(lambda x: x * 2, numbers)
# print(list(result))
#
#  2. filter()
#
# Filters items from an iterable based on a condition
#
# Returns only the values for which the function returns True
#
# Example:
#
# numbers = [1, 2, 3, 4]
# result = filter(lambda x: x > 2, numbers)
# print(list(result))
#
#  3. reduce()
#
# Performs a cumulative operation on elements
#
# Returns a single value
#
# Present in functools module
#
# Example:
#
# from functools import reduce
# numbers = [1, 2, 3, 4]
# result = reduce(lambda x, y: x + y, numbers)
# print(result)

# %% [markdown]
# Ques 11:-Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given
# list:[47,11,42,13];
#
# Answer:-The answer is :-
# ![question 11.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #Practical Questions

# %%
#Ques 1:-. Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in
#the list.

def sum_even(numbers):
    total = 0
    for num in numbers:
        if num % 2 == 0:
            total += num
    return total

# Taking list input from user
l1 = list(map(int, input("Enter numbers separated by space: ").split()))

result = sum_even(l1)
print("Sum of even numbers =", result)
# Out:
# Enter numbers separated by space: 24 46
# Sum of even numbers = 70

# %%
#Ques 2:-Create a Python function that accepts a string and returns the reverse of that string.

reverse_string= (input("enter the string:"))
print(reverse_string[::-1])
# Out:
# enter the string:i am avika
#  akiva ma i

# %%
#Ques 3:- Implement a Python function that takes a list of integers and returns a new list containing the squares of
#each number.

def square_list(numbers):
    sq = []
    for i in numbers:
        sq.append(i ** 2)
    return sq


l3 = list(map(int, input("Enter numbers separated by space: ").split()))

print("Squares of numbers:", square_list(l3))
# Out:
# Enter numbers separated by space: 3 4 5 6 3 4
# Squares of numbers: [9, 16, 25, 36, 9, 16]

# %%
#Ques 4:- Write a Python function that checks if a given number is prime or not from 1 to 200
def is_prime(n):
    if n < 2:
        print(n, "is NOT a prime number")
        return

    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            print(n, "is NOT a prime number")
            return

    print(n, "is a PRIME number")

num = int(input("Enter a number: "))
is_prime(num)
# Out:
# Enter a number: 3
# 3 is a PRIME number

# %%
#Ques 5:- Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of
#terms.
class Fibonacci:
    def __init__(self, n):
        self.n = n
        self.a = 0
        self.b = 1
        self.count = 0

    def __iter__(self):
        return self

    def __next__(self):
        if self.count < self.n:
            result = self.a
            self.a, self.b = self.b, self.a + self.b
            self.count += 1
            return result
        else:
            raise StopIteration


num = int(input("Enter number of terms: "))
fib = Fibonacci(num)

for value in fib:
    print(value)
# Out:
# Enter number of terms: 4
# 0
# 1
# 1
# 2

# %%
#Ques 6:-Write a generator function in Python that yields the powers of 2 up to a given exponent.

def power_of_two(n):
    for i in range(n + 1):
        yield 2 ** i



num = int(input("Enter the maximum exponent: "))


for value in power_of_two(num):
    print(value)
# Out:
# Enter the maximum exponent: 3
# 1
# 2
# 4
# 8

# %%
#Ques 7:-Implement a generator function that reads a file line by line and yields each line as a string.

# Create sample file
with open("sample.txt", "w") as f:
    f.write("Hello\n")
    f.write("This is Python\n")
    f.write("Reading file line by line\n")


# Generator function
def read_file_line_by_line(filename):
    with open(filename, "r") as file:
        for line in file:
            yield line.strip()


file_name = "sample.txt"

# Read file line by line
for line in read_file_line_by_line(file_name):
    print(line)
# Out:
# Hello
# This is Python
# Reading file line by line

# %%
#Ques 8:- Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.



data = [(2, 5), (1, 3), (4, 1), (6, 2)]


sorted_list = sorted(data, key = lambda x: x[1])

print(sorted_list)
# Out:
# [(4, 1), (6, 2), (1, 3), (2, 5)]

# %%
#Ques 9 :-Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit.

# List of temperatures in Celsius
celsius_temp = [0, 10, 20, 30, 40]

# Convert to Fahrenheit using map and lambda
fahrenheit_temp = list(map(lambda c: (c * 9/5) + 32, celsius_temp))

print("Temperatures in Celsius:", celsius_temp)
print("Temperatures in Fahrenheit:", fahrenheit_temp)
# Out:
# Temperatures in Celsius: [0, 10, 20, 30, 40]
# Temperatures in Fahrenheit: [32.0, 50.0, 68.0, 86.0, 104.0]

# %%
#Ques 10:- Create a Python program that uses `filter()` to remove all the vowels from a given string.

text = "Hello Python World"

vowels = "aeiouAEIOU"

result = ''.join(filter(lambda ch: ch not in vowels, text))

print("Original string:", text)
print("String after removing vowels:", result)
# Out:
# Original string: Hello Python World
# String after removing vowels: Hll Pythn Wrld

# %%
#Ques 11:- Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this:


orders = [
    [34587, "Learning Python, Mark Lutz", 4, 40.95],
    [98762, "Programming Python, Mark Lutz", 5, 56.80],
    [77226, "Head First Python, Paul Barry", 3, 32.95],
    [88112, "Einführung in Python3, Bernd Klein", 3, 24.99]
]


final_orders = list(
    map(lambda x: (x[0], x[2]*x[3] if x[2]*x[3] >= 100 else x[2]*x[3] + 10), orders)
)

print("Final Billing List:")
print(final_orders)
# Out:
# Final Billing List:
# [(34587, 163.8), (98762, 284.0), (77226, 108.85000000000001), (88112, 84.97)]
